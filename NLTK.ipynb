# %% [markdown]
# <a href="https://colab.research.google.com/github/jennif8r/NLP/blob/main/NLTK.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Natural Language Toolkit (NLTK)**
#
# O Natural Language Toolkit (NLTK) é uma das bibliotecas mais antigas e populares para Processamento de Linguagem Natural (PLN) em Python. Desenvolvida para ser uma ferramenta educativa, ela é amplamente utilizada tanto por iniciantes quanto por profissionais da área. O NLTK oferece uma variedade de recursos que facilitam a análise e manipulação de texto.
#
# Principais funcionalidades do NLTK:
#
#  - Tokenization
#  - Stemming
#  - Tagging
#  - Parsing

# %% [markdown]
# ##Configurando o ambiente

# %%
import nltk
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer, WordNetLemmatizer, SnowballStemmer, LancasterStemmer
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.tag import pos_tag_sents
import string
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
nltk.download('tagsets')
nltk.download('maxent_ne_chunker')
nltk.download('words')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package tagsets to /root/nltk_data...
# [nltk_data]   Unzipping help/tagsets.zip.
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping chunkers/maxent_ne_chunker.zip.
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Unzipping corpora/words.zip.
# True

# %%
texto= "Nós somos feitos de poeira de estrelas. Nós somos uma maneira de o cosmos se autoconhecer. A imaginação nos leva a mundos que nunca sequer existiram. Mas sem ela não vamos a lugar algum."
print(texto)
# Out:
# Nós somos feitos de poeira de estrelas. Nós somos uma maneira de o cosmos se autoconhecer. A imaginação nos leva a mundos que nunca sequer existiram. Mas sem ela não vamos a lugar algum.

# %% [markdown]
# ##Tokenization
# Tokenização é o processo de dividir um texto em unidades menores chamadas tokens.
#
# - **Tokenização de Palavras:** Divide um texto em palavras individuais chamadas tokens. Exemplo: "Eu adoro programação" torna-se ["Eu", "adoro", "programação"].
#
# - **Tokenização de Sentenças:** Divide um texto em sentenças individuais. Exemplo: "Eu adoro programação. Ela é muito interessante." torna-se ["Eu adoro programação.", "Ela é muito interessante."].
#
#
#
# ![image.png](data:image/png;base64,...)

# %%
#Tokenização de sentenças:
sentencas = sent_tokenize(texto, language="portuguese")
print(type(sentencas))
print(sentencas)
# Out:
# <class 'list'>
# ['Nós somos feitos de poeira de estrelas.', 'Nós somos uma maneira de o cosmos se autoconhecer.', 'A imaginação nos leva a mundos que nunca sequer existiram.', 'Mas sem ela não vamos a lugar algum.']

# %%
#Tokenização de palavras:
tokens = word_tokenize(texto, language="portuguese")
print(len(tokens))
print(tokens)
# Out:
# 38
# ['Nós', 'somos', 'feitos', 'de', 'poeira', 'de', 'estrelas', '.', 'Nós', 'somos', 'uma', 'maneira', 'de', 'o', 'cosmos', 'se', 'autoconhecer', '.', 'A', 'imaginação', 'nos', 'leva', 'a', 'mundos', 'que', 'nunca', 'sequer', 'existiram', '.', 'Mas', 'sem', 'ela', 'não', 'vamos', 'a', 'lugar', 'algum', '.']

# %% [markdown]
# ##Gerenciando Stop Words e Pontuação
# No processamento de linguagem natural (PLN), o gerenciamento de stop words e pontuação é essencial para a limpeza e preparação de texto.
#
#   - **Stop Words**:
# Stop words são palavras comuns que geralmente não carregam muito significado e podem ser removidas para melhorar a eficiência da análise. Exemplos incluem artigos, preposições e conjunções como "o", "e", "mas". No NLTK, você pode acessar uma lista predefinida de stop words e personalizá-la conforme necessário.
#
# - **Pontuação**:
# A pontuação pode ser removida para evitar ruído na análise do texto. Isso inclui símbolos como ".", ",", "!", "?". O NLTK permite facilmente a filtragem desses caracteres.
#
# Ao gerenciar stop words e pontuação, você torna o texto mais limpo e focado em termos mais significativos, melhorando assim a qualidade das análises subsequentes.
#
# ![image.png](data:image/png;base64,...)

# %%
#Stop Words lista:
stops = stopwords.words("portuguese")
print(len(stops))
print(stops)
# Out:
# 207
# ...

# %%
#removendo os stop words do documento
palavras_sem_stop = [palavra for palavra in tokens if palavra not in stops]
print("Texto original: ",texto)
print(len(palavras_sem_stop))
print(palavras_sem_stop)
# Out:
# Texto original:  Nós somos feitos de poeira de estrelas. Nós somos uma maneira de o cosmos se autoconhecer. A imaginação nos leva a mundos que nunca sequer existiram. Mas sem ela não vamos a lugar algum.
# 23
# ['Nós', 'feitos', 'poeira', 'estrelas', '.', 'Nós', 'maneira', 'cosmos', 'autoconhecer', '.', 'A', 'imaginação', 'leva', 'mundos', 'nunca', 'sequer', 'existiram', '.', 'Mas', 'vamos', 'lugar', 'algum', '.']

# %%
#ver a list de pontuação:
print(string.punctuation)

# %%
#remover a pontuação do documento:
palavras_sem_pontuacao = [palavra for palavra in palavras_sem_stop if palavra not in string.punctuation]
print("Texto original: ",texto)
print(len(palavras_sem_pontuacao))
print(palavras_sem_pontuacao)
# Out:
# Texto original:  Nós somos feitos de poeira de estrelas. Nós somos uma maneira de o cosmos se autoconhecer. A imaginação nos leva a mundos que nunca sequer existiram. Mas sem ela não vamos a lugar algum.
# 19
# ['Nós', 'feitos', 'poeira', 'estrelas', 'Nós', 'maneira', 'cosmos', 'autoconhecer', 'A', 'imaginação', 'leva', 'mundos', 'nunca', 'sequer', 'existiram', 'Mas', 'vamos', 'lugar', 'algum']

# %% [markdown]
# ##Produzindo Métrica
# No processamento de linguagem natural (PLN), produzir métricas é essencial para avaliar e entender o desempenho de modelos e técnicas aplicadas ao texto. Utilizando a biblioteca NLTK, é possível calcular diversas métricas sobre a análise textual.

# %% [markdown]
# ####   **Frequência de Palavras:**
# A frequência de palavras ajuda a identificar quais palavras aparecem com mais frequência em um texto. Isso pode ser útil para identificar termos importantes ou tópicos predominantes.

# %%
#Ver a frequencia que aparece as palavras
frequencia = nltk.FreqDist(palavras_sem_pontuacao)
print(frequencia)
frequencia
# Out:
# <FreqDist with 18 samples and 19 outcomes>
# FreqDist({'Nós': 2, 'feitos': 1, 'poeira': 1, 'estrelas': 1, 'maneira': 1, 'cosmos': 1, 'autoconhecer': 1, 'A': 1, 'imaginação': 1, 'leva': 1, ...})

# %%
mais_comuns = frequencia.most_common(5)
print(mais_comuns)
# Out:
# [('Nós', 2), ('feitos', 1), ('poeira', 1), ('estrelas', 1), ('maneira', 1)]

# %% [markdown]
# ##Stemming
#
# - Porter: Mais comum e mais antigo
# - Snowball: Melhorado com relação do Porter. Melhor performance computacional.

# %% [markdown]
# ![image.png](data:image/png;base64,...)
