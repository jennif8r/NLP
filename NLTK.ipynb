# %% [markdown]
# <a href="https://colab.research.google.com/github/jennif8r/NLP/blob/main/NLTK.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Natural Language Toolkit (NLTK)**
#
# O Natural Language Toolkit (NLTK) é uma das bibliotecas mais antigas e populares para Processamento de Linguagem Natural (PLN) em Python. Desenvolvida para ser uma ferramenta educativa, ela é amplamente utilizada tanto por iniciantes quanto por profissionais da área. O NLTK oferece uma variedade de recursos que facilitam a análise e manipulação de texto.
#
# Principais funcionalidades do NLTK:
#
#  - Tokenization
#  - Stemming
#  - Tagging
#  - Parsing

# %% [markdown]
# ##Configurando o ambiente

# %%
 # !pip install nltk==3.3
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 11.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for nltk: filename=nltk-3.3-py3-none-any.whl size=1394472 sha256=585b5d91c418078aa919b88e0601c4d7f28b19d8fa09c8c5d89582eaaf7d544d
#   Stored in directory: /root/.cache/pip/wheels/6b/6d/14/3defa4cd7013faeddf715150696f4a96d7725c87700eb8a68e
# Successfully built nltk
# ...
#   Attempting uninstall: nltk
#     Found existing installation: nltk 3.8.1
#     Uninstalling nltk-3.8.1:
#       Successfully uninstalled nltk-3.8.1
# ...

# %%
import nltk
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer, WordNetLemmatizer, SnowballStemmer, LancasterStemmer
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.tag import pos_tag_sents
import string
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
nltk.download('tagsets')
nltk.download('maxent_ne_chunker')
nltk.download('words')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package tagsets to /root/nltk_data...
# [nltk_data]   Unzipping help/tagsets.zip.
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping chunkers/maxent_ne_chunker.zip.
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Unzipping corpora/words.zip.
# True

# %%
texto= "Nós somos feitos de poeira de estrelas. Nós somos uma maneira de o cosmos se autoconhecer. A imaginação nos leva a mundos que nunca sequer existiram. Mas sem ela não vamos a lugar algum."
print(texto)
# Out:
# Nós somos feitos de poeira de estrelas. Nós somos uma maneira de o cosmos se autoconhecer. A imaginação nos leva a mundos que nunca sequer existiram. Mas sem ela não vamos a lugar algum.

# %% [markdown]
# ##Tokenization
# Tokenização é o processo de dividir um texto em unidades menores chamadas tokens.
#
# - **Tokenização de Palavras:** Divide um texto em palavras individuais chamadas tokens. Exemplo: "Eu adoro programação" torna-se ["Eu", "adoro", "programação"].
#
# - **Tokenização de Sentenças:** Divide um texto em sentenças individuais. Exemplo: "Eu adoro programação. Ela é muito interessante." torna-se ["Eu adoro programação.", "Ela é muito interessante."].
#
#
#
# ![image.png](data:image/png;base64,...)

# %%
#Tokenização de sentenças:
sentencas = sent_tokenize(texto, language="portuguese")
print(type(sentencas))
print(sentencas)
# Out:
# <class 'list'>
# ['Nós somos feitos de poeira de estrelas.', 'Nós somos uma maneira de o cosmos se autoconhecer.', 'A imaginação nos leva a mundos que nunca sequer existiram.', 'Mas sem ela não vamos a lugar algum.']

# %%
#Tokenização de palavras:
tokens = word_tokenize(texto, language="portuguese")
print(len(tokens))
print(tokens)
# Out:
# 38
# ['Nós', 'somos', 'feitos', 'de', 'poeira', 'de', 'estrelas', '.', 'Nós', 'somos', 'uma', 'maneira', 'de', 'o', 'cosmos', 'se', 'autoconhecer', '.', 'A', 'imaginação', 'nos', 'leva', 'a', 'mundos', 'que', 'nunca', 'sequer', 'existiram', '.', 'Mas', 'sem', 'ela', 'não', 'vamos', 'a', 'lugar', 'algum', '.']

# %% [markdown]
# ##Gerenciando Stop Words e Pontuação
# No processamento de linguagem natural (PLN), o gerenciamento de stop words e pontuação é essencial para a limpeza e preparação de texto.
#
#   - **Stop Words**:
# Stop words são palavras comuns que geralmente não carregam muito significado e podem ser removidas para melhorar a eficiência da análise. Exemplos incluem artigos, preposições e conjunções como "o", "e", "mas". No NLTK, você pode acessar uma lista predefinida de stop words e personalizá-la conforme necessário.
#
# - **Pontuação**:
# A pontuação pode ser removida para evitar ruído na análise do texto. Isso inclui símbolos como ".", ",", "!", "?". O NLTK permite facilmente a filtragem desses caracteres.
#
# Ao gerenciar stop words e pontuação, você torna o texto mais limpo e focado em termos mais significativos, melhorando assim a qualidade das análises subsequentes.
#
# ![image.png](data:image/png;base64,...)

# %%
#Stop Words lista:
stops = stopwords.words("portuguese")
print(len(stops))
print(stops)
# Out:
# 207
# ...

# %%
#removendo os stop words do documento
palavras_sem_stop = [palavra for palavra in tokens if palavra not in stops]
print("Texto original: ",texto)
print(len(palavras_sem_stop))
print(palavras_sem_stop)
# Out:
# Texto original:  Nós somos feitos de poeira de estrelas. Nós somos uma maneira de o cosmos se autoconhecer. A imaginação nos leva a mundos que nunca sequer existiram. Mas sem ela não vamos a lugar algum.
# 23
# ['Nós', 'feitos', 'poeira', 'estrelas', '.', 'Nós', 'maneira', 'cosmos', 'autoconhecer', '.', 'A', 'imaginação', 'leva', 'mundos', 'nunca', 'sequer', 'existiram', '.', 'Mas', 'vamos', 'lugar', 'algum', '.']

# %%
#ver a list de pontuação:
print(string.punctuation)
# Out:
# !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~

# %%
#remover a pontuação do documento:
palavras_sem_pontuacao = [palavra for palavra in palavras_sem_stop if palavra not in string.punctuation]
print("Texto original: ",texto)
print(len(palavras_sem_pontuacao))
print(palavras_sem_pontuacao)
# Out:
# Texto original:  Nós somos feitos de poeira de estrelas. Nós somos uma maneira de o cosmos se autoconhecer. A imaginação nos leva a mundos que nunca sequer existiram. Mas sem ela não vamos a lugar algum.
# 19
# ['Nós', 'feitos', 'poeira', 'estrelas', 'Nós', 'maneira', 'cosmos', 'autoconhecer', 'A', 'imaginação', 'leva', 'mundos', 'nunca', 'sequer', 'existiram', 'Mas', 'vamos', 'lugar', 'algum']

# %% [markdown]
# ##Produzindo Métrica
# No processamento de linguagem natural (PLN), produzir métricas é essencial para avaliar e entender o desempenho de modelos e técnicas aplicadas ao texto. Utilizando a biblioteca NLTK, é possível calcular diversas métricas sobre a análise textual.

# %% [markdown]
# ####   **Frequência de Palavras:**
# A frequência de palavras ajuda a identificar quais palavras aparecem com mais frequência em um texto. Isso pode ser útil para identificar termos importantes ou tópicos predominantes.

# %%
#Ver a frequencia que aparece as palavras
frequencia = nltk.FreqDist(palavras_sem_pontuacao)
print(frequencia)
frequencia
# Out:
# <FreqDist with 18 samples and 19 outcomes>
# FreqDist({'Nós': 2, 'feitos': 1, 'poeira': 1, 'estrelas': 1, 'maneira': 1, 'cosmos': 1, 'autoconhecer': 1, 'A': 1, 'imaginação': 1, 'leva': 1, ...})

# %%
mais_comuns = frequencia.most_common(5)
print(mais_comuns)
# Out:
# [('Nós', 2), ('feitos', 1), ('poeira', 1), ('estrelas', 1), ('maneira', 1)]

# %% [markdown]
# ## Stemming
#
# Stemming é uma técnica utilizada no processamento de linguagem natural (NLP) que consiste em reduzir palavras a suas raízes ou radicais. O objetivo é simplificar a análise de textos, reduzindo palavras com significados semelhantes à sua forma base. Isso é especialmente útil em tarefas como busca de informações e análise de texto, onde queremos que variações de uma palavra sejam tratadas da mesma forma. Existem vários algoritmos de stemming, cada um com suas características:
#
# - **Porter:** É o algoritmo de stemming mais comum e mais antigo, desenvolvido por Martin Porter em 1980. Ele utiliza um conjunto de regras para remover sufixos das palavras. Embora seja eficiente e amplamente utilizado, às vezes pode produzir resultados que não são palavras reais.
#
# - **Snowball:** Também conhecido como Porter2, é uma versão aprimorada do algoritmo Porter. Desenvolvido pelo mesmo autor, o Snowball oferece melhor desempenho computacional e resultados mais precisos. Ele é mais robusto e flexível, adaptando-se melhor a diferentes idiomas.
#
# - **Lancaster:** É um algoritmo de stemming mais agressivo, o que significa que ele tende a cortar mais caracteres das palavras. Embora isso possa ser útil para algumas aplicações, os resultados nem sempre são intuitivos ou fáceis de entender, pois ele pode reduzir palavras a formas muito curtas ou incomuns.
#
# Cada um desses algoritmos tem suas vantagens e desvantagens, e a escolha de qual usar depende da aplicação específica e do equilíbrio desejado entre precisão e simplicidade.
#
# ![image.png](data:image/png;base64,...)

# %%
#Exemplo de Porter:
stemmer = PorterStemmer()
stem1 = [stemmer.stem(word) for word in palavras_sem_stop]

print( palavras_sem_pontuacao)
print( stem1)
# Out:
# ['Nós', 'feitos', 'poeira', 'estrelas', 'Nós', 'maneira', 'cosmos', 'autoconhecer', 'A', 'imaginação', 'leva', 'mundos', 'nunca', 'sequer', 'existiram', 'Mas', 'vamos', 'lugar', 'algum']
# ['nó', 'feito', 'poeira', 'estrela', '.', 'nó', 'maneira', 'cosmo', 'autoconhec', '.', 'A', 'imaginação', 'leva', 'mundo', 'nunca', 'sequer', 'existiram', '.', 'ma', 'vamo', 'lugar', 'algum', '.']

# %%
#Snowball:
stemmer2 = SnowballStemmer('portuguese')
stem2 = [stemmer2.stem(word) for word in palavras_sem_stop]

print( palavras_sem_pontuacao)
print( stem2)
# Out:
# ['Nós', 'feitos', 'poeira', 'estrelas', 'Nós', 'maneira', 'cosmos', 'autoconhecer', 'A', 'imaginação', 'leva', 'mundos', 'nunca', 'sequer', 'existiram', 'Mas', 'vamos', 'lugar', 'algum']
# ['nós', 'feit', 'poeir', 'estrel', '.', 'nós', 'maneir', 'cosm', 'autoconhec', '.', 'a', 'imagin', 'lev', 'mund', 'nunc', 'sequ', 'exist', '.', 'mas', 'vam', 'lug', 'algum', '.']

# %%
#Lancaster:
stemmer3 = LancasterStemmer()
stem3 = [stemmer3.stem(word) for word in palavras_sem_stop]

print( palavras_sem_pontuacao)
print( stem3)
# Out:
# ['Nós', 'feitos', 'poeira', 'estrelas', 'Nós', 'maneira', 'cosmos', 'autoconhecer', 'A', 'imaginação', 'leva', 'mundos', 'nunca', 'sequer', 'existiram', 'Mas', 'vamos', 'lugar', 'algum']
# ['nós', 'feito', 'poeir', 'estrela', '.', 'nós', 'maneir', 'cosmo', 'autoconhec', '.', 'a', 'imaginação', 'lev', 'mundo', 'nunc', 'sequ', 'existiram', '.', 'mas', 'vamo', 'lug', 'alg', '.']

# %% [markdown]
# ## Pós-Taggin
#
# OS-Tagging, ou marcação de partes do discurso, é a técnica de atribuir etiquetas gramaticais a palavras em um texto, indicando se são substantivos, verbos, adjetivos, etc. Isso ajuda a entender a função de cada palavra dentro da frase.
#
#
# ![image.png](data:image/png;base64,...)

# %%
#mostrar todas as siglas para marcar, e sua descrição:
nltk.help.upenn_tagset()
# Out:
# $: dollar
#     $ -$ --$ A$ C$ HK$ M$ NZ$ S$ U.S.$ US$
# '': closing quotation mark
#     ' ''
# (: opening parenthesis
#     ( [ {
# ): closing parenthesis
#     ) ] }
# ,: comma
#     ,
# --: dash
#     --
# .: sentence terminator
#     . ! ?
# :: colon or ellipsis
#     : ; ...
# CC: conjunction, coordinating
#     & 'n and both but either et for less minus neither nor or plus so
#     therefore times v. versus vs. whether yet
# CD: numeral, cardinal
#     mid-1890 nine-thirty forty-two one-tenth ten million 0.5 one forty-
#     seven 1987 twenty '79 zero two 78-degrees eighty-four IX '60s .025
#     fifteen 271,124 dozen quintillion DM2,000 ...
# DT: determiner
#     all an another any both del each either every half la many much nary
#     neither no some such that the them these this those
# EX: existential there
#     there
# FW: foreign word
#     gemeinschaft hund ich jeux habeas Haementeria Herr K'ang-si vous
# ...

# %%
#observação para funcionar o nltk tem que está na versão 3.3
pos = nltk.pos_tag(palavras_sem_pontuacao, lang="port")
print(pos)
# Out:
# [('Nós', 'NNP'), ('feitos', 'NN'), ('poeira', 'NN'), ('estrelas', 'NNS'), ('Nós', 'NNP'), ('maneira', 'NN'), ('cosmos', 'NN'), ('autoconhecer', 'VBZ'), ('A', 'DT'), ('imaginação', 'JJ'), ('leva', 'NN'), ('mundos', 'NN'), ('nunca', 'JJ'), ('sequer', 'NN'), ('existiram', 'NN'), ('Mas', 'NNP'), ('vamos', 'NN'), ('lugar', 'NN'), ('algum', 'NN')]

# %%
#tokens da setença:
token2 = sent_tokenize(texto)

ntokens = []
for tokensentenca in token2:
  ntokens.append(word_tokenize(tokensentenca))

print(ntokens)

possentenca = pos_tag_sents(ntokens)
print(possentenca)
# Out:
# [['Nós', 'somos', 'feitos', 'de', 'poeira', 'de', 'estrelas', '.'], ['Nós', 'somos', 'uma', 'maneira', 'de', 'o', 'cosmos', 'se', 'autoconhecer', '.'], ['A', 'imaginação', 'nos', 'leva', 'a', 'mundos', 'que', 'nunca', 'sequer', 'existiram', '.'], ['Mas', 'sem', 'ela', 'não', 'vamos', 'a', 'lugar', 'algum', '.']]
# [[('Nós', 'NNP'), ('somos', 'VBD'), ('feitos', 'NNS'), ('de', 'FW'), ('poeira', 'FW'), ('de', 'FW'), ('estrelas', 'FW'), ('.', '.')], [('Nós', 'NNP'), ('somos', 'NN'), ('uma', 'JJ'), ('maneira', 'NN'), ('de', 'IN'), ('o', 'FW'), ('cosmos', 'NNS'), ('se', 'JJ'), ('autoconhecer', 'NN'), ('.', '.')], [('A', 'DT'), ('imaginação', 'JJ'), ('nos', 'JJ'), ('leva', 'NN'), ('a', 'DT'), ('mundos', 'NN'), ('que', 'NN'), ('nunca', 'JJ'), ('sequer', 'NN'), ('existiram', 'NN'), ('.', '.')], [('Mas', 'NNP'), ('sem', 'NN'), ('ela', 'NN'), ('não', 'JJ'), ('vamos', 'NN'), ('a', 'DT'), ('lugar', 'NN'), ('algum', 'NN'), ('.', '.')]]

# %% [markdown]
# ##Lemmatization
# Lemmatization é a técnica de reduzir palavras à sua forma base ou lema, considerando o contexto e a morfologia das palavras. Diferente do stemming, que apenas remove sufixos, a lematização resulta em formas base reais e corretas.
#
# Por exemplo, a lematização transforma palavras como "amando", "amado" e "amarei" para o lema "amar". Isso ajuda a unificar diferentes formas de uma palavra, tornando a análise de texto mais precisa.
#
# ![image.png](data:image/png;base64,...)

# %%
#Não está funcionando a Lemmatization na bliblioteca NLTK versão 3.3, e estava usando essa versão por causa do portugues que é a unica que está funcionando esse idioma, com isso vamos apaixar a versão mais recente do nltk 3.8.1 e fazer um exemplo em ingles para podermos ver a lemmatizarion e comparar com a Stemming
# !pip install nltk==3.8.1

# %%
import nltk
from nltk.corpus import wordnet
from nltk.stem import WordNetLemmatizer, PorterStemmer
from nltk.tokenize import word_tokenize

# Download necessário para lematização e stemming
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
# Função para obter a tag do WordNet a partir da tag do POS do NLTK
def get_wordnet_pos(treebank_tag):
    if treebank_tag.startswith('J'):
        return wordnet.ADJ
    elif treebank_tag.startswith('V'):
        return wordnet.VERB
    elif treebank_tag.startswith('N'):
        return wordnet.NOUN
    elif treebank_tag.startswith('R'):
        return wordnet.ADV
    else:
        return wordnet.NOUN

# Exemplo de texto
texto = "change changing changes changed changer"
print("Texto:", texto)

# Tokenização de palavras
tokens = word_tokenize(texto)

# POS-Tagging
pos_tags = nltk.pos_tag(tokens)

# Lematização
lemmatizer = WordNetLemmatizer()
lemmas = [lemmatizer.lemmatize(token, get_wordnet_pos(pos)) for token, pos in pos_tags]

# Stemming
stemmer = PorterStemmer()
stems = [stemmer.stem(token) for token in tokens]

print("Tokens:", tokens)
print("POS-Tags:", pos_tags)
print("Lemmatization:", lemmas)
print("Stemming:", stems)
# Out:
# Texto: change changing changes changed changer
# Tokens: ['change', 'changing', 'changes', 'changed', 'changer']
# POS-Tags: [('change', 'NN'), ('changing', 'VBG'), ('changes', 'NNS'), ('changed', 'VBD'), ('changer', 'NN')]
# Lemmatization: ['change', 'change', 'change', 'change', 'changer']
# Stemming: ['chang', 'chang', 'chang', 'chang', 'changer']
